# %%
import matplotlib.pyplot as plt
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
import seaborn as sns
sns.set_theme(context='paper', style='ticks',font='sans-serif')
import numpy as np
import pandas as pd
from filter_adata import adata_filtered

from pathlib import Path
fig = '/Users/nabilazulkapeli/Documents/Honours Thesis 2025/nabs_data'
fig = Path(fig)
# Out:
# adata and clinical merged, rename the columns if you want
# clusters are now annotated with specific and broad cell types
# /Users/nabilazulkapeli/Documents/Honours Thesis 2025/final_data/filter_adata.py:195: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('core_id')
# /Users/nabilazulkapeli/Documents/Honours Thesis 2025/final_data/filter_adata.py:214: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby('core_id')
# low quality cores with <1000 total cells or <100 melanoma cells have been removed
# adata_filtered (both high tumour and peritumour cores) has been created
# ...

# %%
trial = pd.read_excel('/Users/nabilazulkapeli/Documents/Honours Thesis 2025/nabs_data/trial_response_TRAE.xlsx', index_col='ICI')
trial = trial.T
trial = trial.reset_index()
trial
# Out:
# ICI        index Trial   ORR 3/4 TRAEs
# 0     Ipi + Nivo  CM67  58.3      62.2
# 1           Nivo  CM67  44.9      24.6
# 2            Ipi  CM67    19      29.6
# 3    Rela + Nivo   R47  43.7        22

# %%
order = ['Ipi + Nivo', 'Rela + Nivo', 'Nivo', 'Ipi']
sns.barplot(
    data=trial,
    x='index',
    y='ORR',
    palette='tab10',
)
plt.savefig(fig / 'ICI_ORR.pdf', dpi=300, bbox_inches='tight')
# Out:
# /var/folders/3p/y9w6kn9d25q5ppxs6mh5ps3m0000gn/T/ipykernel_62410/3382499356.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
sns.barplot(
    data=trial,
    x='index',
    y='3/4 TRAEs',
    palette='tab10',
)
plt.savefig(fig / 'ICI_TRAEs.pdf', dpi=300, bbox_inches='tight')
# Out:
# /var/folders/3p/y9w6kn9d25q5ppxs6mh5ps3m0000gn/T/ipykernel_62410/2954153308.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
